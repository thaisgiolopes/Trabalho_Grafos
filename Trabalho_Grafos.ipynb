# %% [markdown]
# # Análise de problemas de logística

# %% [markdown]
# ### Configurações iniciais

# %%
# !pip install pandas
import pandas as pd

# !git clone https://github.com/thaisgiolopes/Trabalho_Grafos.git
# %cd Trabalho_Grafos/backend
from grafo import Grafo
# Out:
# ...
# Cloning into 'Trabalho_Grafos'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 94 (delta 20), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (94/94), 88.16 KiB | 3.67 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /content/Trabalho_Grafos/backend

# %% [markdown]
# ### Estatísticas dos problemas
#
# Para visualizar as estatísticas calculadas dos problemas, execute o código abaixo:

# %%
estatisticas_gerais = []
intermediacoes = []

# Lê os nomes dos arquivos
with open("lista_instancias.txt", "r") as arquivo:
    nomes_instancias = [linha.strip() for linha in arquivo if linha.strip()]

# Processa cada instância
for nome_arquivo in nomes_instancias:
    caminho = f"instancias/{nome_arquivo}"
    grafo = Grafo(caminho)
    grafo.gerar_matriz_caminhos()

    estatisticas, intermed = grafo.calcular_estatisticas()
    estatisticas["instancia"] = nome_arquivo
    estatisticas_gerais.append(estatisticas)

    for no, valor in intermed.items():
        intermediacoes.append({
            "instancia": nome_arquivo,
            "vertice": no,
            "centralidade_intermediacao": valor
        })

# Cria DataFrames
df_estatisticas = pd.DataFrame(estatisticas_gerais)
# Reordena as colunas para que "instancia" fique em primeiro
colunas = ["instancia"] + [col for col in df_estatisticas.columns if col != "instancia"]
df_estatisticas = df_estatisticas[colunas]
df_intermediacao = pd.DataFrame(intermediacoes)

# Exibe tabelas
print("📊 Estatísticas Gerais por Instância:")
display(df_estatisticas)

print("📊 Centralidade de Intermediação por Vértice:")
display(df_intermediacao)

# Salva como CSV
df_estatisticas.to_csv("estatisticas_gerais.csv", index=False)
df_intermediacao.to_csv("centralidade_intermediacao.csv", index=False)
# Out:
# 📊 Estatísticas Gerais por Instância:
#                  instancia  vértices  arestas  arcos  nós requeridos  \
# 0                 BHW1.dat        12       11     22               7
# 1                 BHW2.dat        12        0     25               4
# 2                 BHW3.dat        13        8     30               5
# 3                 BHW4.dat        11        0     44               6
# 4                 BHW5.dat        40        0    132              30
# 5                 BHW6.dat        40       37     58              15
# 6                 BHW7.dat        50        0    194              35
# 7                 BHW8.dat        50        0    194              20
# 8                 BHW9.dat        50       26    142              10
# 9                BHW10.dat        77        0    196              40
# 10             CBMix11.dat        69        6    229              65
# 11             CBMix12.dat        38        0     71               1
# ...

# %% [markdown]
# ### Arquivo com as estatísticas
#
# Caso deseje baixar o arquivo com as estatísticas, execute o código abaixo:

# %%
from google.colab import files
files.download("estatisticas_gerais.csv")
files.download("centralidade_intermediacao.csv")
